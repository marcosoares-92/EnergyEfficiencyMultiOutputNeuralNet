# %% [markdown]
# # Ungraded Lab: Build a Multi-output Model
#
# In this lab, we'll show how you can build models with more than one output. The dataset we will be working on is available from the [UCI Machine Learning Repository](https://archive.ics.uci.edu/ml/datasets/Energy+efficiency). It is an Energy Efficiency dataset which uses the bulding features (e.g. wall area, roof area) as inputs and has two outputs: Cooling Load and Heating Load. Let's see how we can build a model to train on this data.

# %% [markdown]
# ## Imports

# %%
try:
  # %tensorflow_version only exists in Colab.
  # %tensorflow_version 2.x
except Exception:
  pass

import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Input
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Utilities
#
# We define a few utilities for data conversion and visualization to make our code more neat.

# %%
def format_output(data):
    y1 = data.pop('Y1')
    y1 = np.array(y1)
    y2 = data.pop('Y2')
    y2 = np.array(y2)
    return y1, y2


def norm(x):
    return (x - train_stats['mean']) / train_stats['std']


def plot_diff(y_true, y_pred, title=''):
    plt.scatter(y_true, y_pred)
    plt.title(title)
    plt.xlabel('True Values')
    plt.ylabel('Predictions')
    plt.axis('equal')
    plt.axis('square')
    plt.xlim(plt.xlim())
    plt.ylim(plt.ylim())
    plt.plot([-100, 100], [-100, 100])
    plt.show()


def plot_metrics(metric_name, title, ylim=5):
    plt.title(title)
    plt.ylim(0, ylim)
    plt.plot(history.history[metric_name], color='blue', label=metric_name)
    plt.plot(history.history['val_' + metric_name], color='green', label='val_' + metric_name)
    plt.show()

# %% [markdown]
# ## Prepare the Data
#
# We download the dataset and format it for training.

# %%
# Specify data URI
URI = './data/ENB2012_data.xlsx'

# Use pandas excel reader
df = pd.read_excel(URI)
df = df.sample(frac=1).reset_index(drop=True)

# Split the data into train and test with 80 train / 20 test
train, test = train_test_split(df, test_size=0.2)
train_stats = train.describe()

# Get Y1 and Y2 as the 2 outputs and format them as np arrays
train_stats.pop('Y1')
train_stats.pop('Y2')
train_stats = train_stats.transpose()
train_Y = format_output(train)
test_Y = format_output(test)

# Normalize the training and test data
norm_train_X = norm(train)
norm_test_X = norm(test)

# %% [markdown]
# ## Build the Model
#
# Here is how we'll build the model using the functional syntax. Notice that we can specify a list of outputs (i.e. `[y1_output, y2_output]`) when we instantiate the `Model()` class.

# %%
# Define model layers.
input_layer = Input(shape=(len(train .columns),))
first_dense = Dense(units='128', activation='relu')(input_layer)
second_dense = Dense(units='128', activation='relu')(first_dense)

# Y1 output will be fed directly from the second dense
y1_output = Dense(units='1', name='y1_output')(second_dense)
third_dense = Dense(units='64', activation='relu')(second_dense)

# Y2 output will come via the third dense
y2_output = Dense(units='1', name='y2_output')(third_dense)

# Define the model with the input layer and a list of output layers
model = Model(inputs=input_layer, outputs=[y1_output, y2_output])

print(model.summary())
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 8)]          0
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 128)          1152        input_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 128)          16512       dense[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 64)           8256        dense_1[0][0]
# __________________________________________________________________________________________________
# y1_output (Dense)               (None, 1)            129         dense_1[0][0]
# __________________________________________________________________________________________________
# y2_output (Dense)               (None, 1)            65          dense_2[0][0]
# ==================================================================================================
# Total params: 26,114
# Trainable params: 26,114
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %% [markdown]
# ## Configure parameters
#
# We specify the optimizer as well as the loss and metrics for each output.

# %%
# Specify the optimizer, and compile the model with loss functions for both outputs
optimizer = tf.keras.optimizers.SGD(lr=0.001)
model.compile(optimizer=optimizer,
              loss={'y1_output': 'mse', 'y2_output': 'mse'},
              metrics={'y1_output': tf.keras.metrics.RootMeanSquaredError(),
                       'y2_output': tf.keras.metrics.RootMeanSquaredError()})

# %% [markdown]
# ## Train the Model

# %%
# Train the model for 500 epochs
history = model.fit(norm_train_X, train_Y,
                    epochs=500, batch_size=10, validation_data=(norm_test_X, test_Y))
# Out:
# Train on 614 samples, validate on 154 samples
# Epoch 1/500
# 614/614 [==============================] - 1s 1ms/sample - loss: 242.3255 - y1_output_loss: 114.2339 - y2_output_loss: 126.6407 - y1_output_root_mean_squared_error: 10.7264 - y2_output_root_mean_squared_error: 11.2814 - val_loss: 53.8088 - val_y1_output_loss: 15.8051 - val_y2_output_loss: 36.6168 - val_y1_output_root_mean_squared_error: 4.0434 - val_y2_output_root_mean_squared_error: 6.1205
# Epoch 2/500
# 614/614 [==============================] - 0s 170us/sample - loss: 30.2930 - y1_output_loss: 12.1486 - y2_output_loss: 18.2116 - y1_output_root_mean_squared_error: 3.4738 - y2_output_root_mean_squared_error: 4.2691 - val_loss: 48.9587 - val_y1_output_loss: 20.2625 - val_y2_output_loss: 27.3736 - val_y1_output_root_mean_squared_error: 4.5830 - val_y2_output_root_mean_squared_error: 5.2872
# Epoch 3/500
# 614/614 [==============================] - 0s 151us/sample - loss: 24.9018 - y1_output_loss: 9.8075 - y2_output_loss: 14.9579 - y1_output_root_mean_squared_error: 3.1434 - y2_output_root_mean_squared_error: 3.8757 - val_loss: 26.7598 - val_y1_output_loss: 11.7339 - val_y2_output_loss: 14.7551 - val_y1_output_root_mean_squared_error: 3.4675 - val_y2_output_root_mean_squared_error: 3.8388
# Epoch 4/500
# 614/614 [==============================] - 0s 158us/sample - loss: 22.8507 - y1_output_loss: 9.3819 - y2_output_loss: 13.5565 - y1_output_root_mean_squared_error: 3.0496 - y2_output_root_mean_squared_error: 3.6811 - val_loss: 25.2152 - val_y1_output_loss: 8.9060 - val_y2_output_loss: 15.6760 - val_y1_output_root_mean_squared_error: 3.0225 - val_y2_output_root_mean_squared_error: 4.0099
# Epoch 5/500
# 614/614 [==============================] - 0s 152us/sample - loss: 24.2306 - y1_output_loss: 9.0268 - y2_output_loss: 14.9839 - y1_output_root_mean_squared_error: 3.0184 - y2_output_root_mean_squared_error: 3.8884 - val_loss: 20.8686 - val_y1_output_loss: 9.5194 - val_y2_output_loss: 10.7208 - val_y1_output_root_mean_squared_error: 3.1360 - val_y2_output_root_mean_squared_error: 3.3218
# Epoch 6/500
# 614/614 [==============================] - 0s 155us/sample - loss: 24.0300 - y1_output_loss: 9.1223 - y2_output_loss: 14.9265 - y1_output_root_mean_squared_error: 3.0194 - y2_output_root_mean_squared_error: 3.8618 - val_loss: 84.8405 - val_y1_output_loss: 13.3196 - val_y2_output_loss: 70.5312 - val_y1_output_root_mean_squared_error: 3.6555 - val_y2_output_root_mean_squared_error: 8.4545
# Epoch 7/500
# 614/614 [==============================] - 0s 146us/sample - loss: 23.1492 - y1_output_loss: 8.7945 - y2_output_loss: 14.3813 - y1_output_root_mean_squared_error: 2.9601 - y2_output_root_mean_squared_error: 3.7930 - val_loss: 31.8318 - val_y1_output_loss: 9.9948 - val_y2_output_loss: 21.0088 - val_y1_output_root_mean_squared_error: 3.1942 - val_y2_output_root_mean_squared_error: 4.6507
# Epoch 8/500
# 614/614 [==============================] - 0s 141us/sample - loss: 27.7737 - y1_output_loss: 9.6295 - y2_output_loss: 18.2178 - y1_output_root_mean_squared_error: 3.0882 - y2_output_root_mean_squared_error: 4.2705 - val_loss: 48.5125 - val_y1_output_loss: 13.2817 - val_y2_output_loss: 34.1114 - val_y1_output_root_mean_squared_error: 3.6735 - val_y2_output_root_mean_squared_error: 5.9176
# Epoch 9/500
# 614/614 [==============================] - 0s 146us/sample - loss: 22.6724 - y1_output_loss: 8.7424 - y2_output_loss: 14.1666 - y1_output_root_mean_squared_error: 2.9506 - y2_output_root_mean_squared_error: 3.7371 - val_loss: 42.1412 - val_y1_output_loss: 9.5566 - val_y2_output_loss: 31.5886 - val_y1_output_root_mean_squared_error: 3.1296 - val_y2_output_root_mean_squared_error: 5.6874
# Epoch 10/500
# 614/614 [==============================] - 0s 143us/sample - loss: 20.1168 - y1_output_loss: 7.9412 - y2_output_loss: 12.0577 - y1_output_root_mean_squared_error: 2.8258 - y2_output_root_mean_squared_error: 3.4831 - val_loss: 18.5344 - val_y1_output_loss: 8.0181 - val_y2_output_loss: 9.9719 - val_y1_output_root_mean_squared_error: 2.8727 - val_y2_output_root_mean_squared_error: 3.2065
# Epoch 11/500
# 614/614 [==============================] - 0s 161us/sample - loss: 20.1446 - y1_output_loss: 7.8648 - y2_output_loss: 12.1521 - y1_output_root_mean_squared_error: 2.8125 - y2_output_root_mean_squared_error: 3.4978 - val_loss: 17.8474 - val_y1_output_loss: 7.7618 - val_y2_output_loss: 9.6164 - val_y1_output_root_mean_squared_error: 2.8147 - val_y2_output_root_mean_squared_error: 3.1504
# Epoch 12/500
# 614/614 [==============================] - 0s 139us/sample - loss: 21.8648 - y1_output_loss: 8.5348 - y2_output_loss: 13.3210 - y1_output_root_mean_squared_error: 2.9171 - y2_output_root_mean_squared_error: 3.6545 - val_loss: 33.5696 - val_y1_output_loss: 13.7522 - val_y2_output_loss: 18.9246 - val_y1_output_root_mean_squared_error: 3.7750 - val_y2_output_root_mean_squared_error: 4.3954
# Epoch 13/500
# 614/614 [==============================] - 0s 141us/sample - loss: 19.9527 - y1_output_loss: 7.8084 - y2_output_loss: 12.5566 - y1_output_root_mean_squared_error: 2.7689 - y2_output_root_mean_squared_error: 3.5051 - val_loss: 19.7312 - val_y1_output_loss: 8.6811 - val_y2_output_loss: 10.6306 - val_y1_output_root_mean_squared_error: 2.9530 - val_y2_output_root_mean_squared_error: 3.3183
# Epoch 14/500
# 614/614 [==============================] - 0s 142us/sample - loss: 20.5981 - y1_output_loss: 8.0240 - y2_output_loss: 12.3937 - y1_output_root_mean_squared_error: 2.8445 - y2_output_root_mean_squared_error: 3.5365 - val_loss: 17.3709 - val_y1_output_loss: 7.5314 - val_y2_output_loss: 9.3148 - val_y1_output_root_mean_squared_error: 2.7825 - val_y2_output_root_mean_squared_error: 3.1030
# Epoch 15/500
# 614/614 [==============================] - 0s 146us/sample - loss: 19.5473 - y1_output_loss: 7.7833 - y2_output_loss: 11.9706 - y1_output_root_mean_squared_error: 2.7747 - y2_output_root_mean_squared_error: 3.4421 - val_loss: 34.9863 - val_y1_output_loss: 11.9648 - val_y2_output_loss: 22.3016 - val_y1_output_root_mean_squared_error: 3.5144 - val_y2_output_root_mean_squared_error: 4.7577
# Epoch 16/500
# 614/614 [==============================] - 0s 147us/sample - loss: 20.6325 - y1_output_loss: 7.5261 - y2_output_loss: 12.9186 - y1_output_root_mean_squared_error: 2.7560 - y2_output_root_mean_squared_error: 3.6107 - val_loss: 16.6806 - val_y1_output_loss: 7.2940 - val_y2_output_loss: 8.9389 - val_y1_output_root_mean_squared_error: 2.7469 - val_y2_output_root_mean_squared_error: 3.0225
# Epoch 17/500
# 614/614 [==============================] - 0s 142us/sample - loss: 19.1005 - y1_output_loss: 7.1469 - y2_output_loss: 11.9181 - y1_output_root_mean_squared_error: 2.6837 - y2_output_root_mean_squared_error: 3.4494 - val_loss: 20.8465 - val_y1_output_loss: 6.7951 - val_y2_output_loss: 13.5094 - val_y1_output_root_mean_squared_error: 2.6328 - val_y2_output_root_mean_squared_error: 3.7302
# Epoch 18/500
# 614/614 [==============================] - 0s 148us/sample - loss: 20.3108 - y1_output_loss: 7.2289 - y2_output_loss: 13.0363 - y1_output_root_mean_squared_error: 2.6942 - y2_output_root_mean_squared_error: 3.6127 - val_loss: 23.1507 - val_y1_output_loss: 6.9634 - val_y2_output_loss: 15.7661 - val_y1_output_root_mean_squared_error: 2.6536 - val_y2_output_root_mean_squared_error: 4.0136
# Epoch 19/500
# 614/614 [==============================] - 0s 145us/sample - loss: 19.1055 - y1_output_loss: 7.0004 - y2_output_loss: 11.9791 - y1_output_root_mean_squared_error: 2.6577 - y2_output_root_mean_squared_error: 3.4702 - val_loss: 14.2470 - val_y1_output_loss: 5.9542 - val_y2_output_loss: 7.8731 - val_y1_output_root_mean_squared_error: 2.4733 - val_y2_output_root_mean_squared_error: 2.8513
# Epoch 20/500
# 614/614 [==============================] - 0s 156us/sample - loss: 18.7916 - y1_output_loss: 6.6823 - y2_output_loss: 12.1513 - y1_output_root_mean_squared_error: 2.5812 - y2_output_root_mean_squared_error: 3.4827 - val_loss: 23.9037 - val_y1_output_loss: 10.0572 - val_y2_output_loss: 13.2998 - val_y1_output_root_mean_squared_error: 3.2257 - val_y2_output_root_mean_squared_error: 3.6741
# Epoch 21/500
# 614/614 [==============================] - 0s 148us/sample - loss: 14.7344 - y1_output_loss: 6.0292 - y2_output_loss: 8.7022 - y1_output_root_mean_squared_error: 2.4408 - y2_output_root_mean_squared_error: 2.9626 - val_loss: 18.3192 - val_y1_output_loss: 7.9639 - val_y2_output_loss: 9.8133 - val_y1_output_root_mean_squared_error: 2.8524 - val_y2_output_root_mean_squared_error: 3.1910
# Epoch 22/500
# 614/614 [==============================] - 0s 146us/sample - loss: 16.4778 - y1_output_loss: 6.3877 - y2_output_loss: 10.0970 - y1_output_root_mean_squared_error: 2.5194 - y2_output_root_mean_squared_error: 3.1828 - val_loss: 19.2390 - val_y1_output_loss: 6.4948 - val_y2_output_loss: 12.5821 - val_y1_output_root_mean_squared_error: 2.5890 - val_y2_output_root_mean_squared_error: 3.5406
# Epoch 23/500
# 614/614 [==============================] - 0s 147us/sample - loss: 15.4449 - y1_output_loss: 5.5530 - y2_output_loss: 9.7581 - y1_output_root_mean_squared_error: 2.3656 - y2_output_root_mean_squared_error: 3.1383 - val_loss: 11.7922 - val_y1_output_loss: 4.9783 - val_y2_output_loss: 6.5546 - val_y1_output_root_mean_squared_error: 2.2689 - val_y2_output_root_mean_squared_error: 2.5776
# Epoch 24/500
# 614/614 [==============================] - 0s 143us/sample - loss: 14.1646 - y1_output_loss: 5.5041 - y2_output_loss: 8.5514 - y1_output_root_mean_squared_error: 2.3559 - y2_output_root_mean_squared_error: 2.9350 - val_loss: 12.1729 - val_y1_output_loss: 5.4327 - val_y2_output_loss: 6.5505 - val_y1_output_root_mean_squared_error: 2.3693 - val_y2_output_root_mean_squared_error: 2.5611
# Epoch 25/500
# 614/614 [==============================] - 0s 152us/sample - loss: 13.4052 - y1_output_loss: 5.2833 - y2_output_loss: 8.0345 - y1_output_root_mean_squared_error: 2.3077 - y2_output_root_mean_squared_error: 2.8424 - val_loss: 28.6433 - val_y1_output_loss: 5.9563 - val_y2_output_loss: 21.9013 - val_y1_output_root_mean_squared_error: 2.4727 - val_y2_output_root_mean_squared_error: 4.7465
# Epoch 26/500
# 614/614 [==============================] - 0s 146us/sample - loss: 12.6743 - y1_output_loss: 4.8404 - y2_output_loss: 7.8128 - y1_output_root_mean_squared_error: 2.1967 - y2_output_root_mean_squared_error: 2.8016 - val_loss: 12.7746 - val_y1_output_loss: 5.4615 - val_y2_output_loss: 7.0908 - val_y1_output_root_mean_squared_error: 2.3689 - val_y2_output_root_mean_squared_error: 2.6763
# Epoch 27/500
# 614/614 [==============================] - 0s 149us/sample - loss: 15.5838 - y1_output_loss: 5.6686 - y2_output_loss: 9.8858 - y1_output_root_mean_squared_error: 2.3788 - y2_output_root_mean_squared_error: 3.1504 - val_loss: 16.2164 - val_y1_output_loss: 7.0486 - val_y2_output_loss: 9.1203 - val_y1_output_root_mean_squared_error: 2.6870 - val_y2_output_root_mean_squared_error: 2.9994
# Epoch 28/500
# 614/614 [==============================] - 0s 152us/sample - loss: 13.7949 - y1_output_loss: 4.9899 - y2_output_loss: 9.1454 - y1_output_root_mean_squared_error: 2.2168 - y2_output_root_mean_squared_error: 2.9800 - val_loss: 38.8053 - val_y1_output_loss: 7.0215 - val_y2_output_loss: 30.8648 - val_y1_output_root_mean_squared_error: 2.6814 - val_y2_output_root_mean_squared_error: 5.6228
# Epoch 29/500
# 614/614 [==============================] - 0s 158us/sample - loss: 15.1691 - y1_output_loss: 5.0876 - y2_output_loss: 10.2036 - y1_output_root_mean_squared_error: 2.2576 - y2_output_root_mean_squared_error: 3.1737 - val_loss: 21.5585 - val_y1_output_loss: 7.1075 - val_y2_output_loss: 14.5298 - val_y1_output_root_mean_squared_error: 2.6911 - val_y2_output_root_mean_squared_error: 3.7837
# Epoch 30/500
# 614/614 [==============================] - 0s 158us/sample - loss: 14.4059 - y1_output_loss: 5.0827 - y2_output_loss: 9.1945 - y1_output_root_mean_squared_error: 2.2651 - y2_output_root_mean_squared_error: 3.0455 - val_loss: 9.9360 - val_y1_output_loss: 4.0621 - val_y2_output_loss: 5.7854 - val_y1_output_root_mean_squared_error: 2.0413 - val_y2_output_root_mean_squared_error: 2.4019
# Epoch 31/500
# 614/614 [==============================] - 0s 153us/sample - loss: 11.2386 - y1_output_loss: 4.1631 - y2_output_loss: 6.9929 - y1_output_root_mean_squared_error: 2.0485 - y2_output_root_mean_squared_error: 2.6537 - val_loss: 10.5418 - val_y1_output_loss: 3.8678 - val_y2_output_loss: 6.4690 - val_y1_output_root_mean_squared_error: 2.0011 - val_y2_output_root_mean_squared_error: 2.5569
# Epoch 32/500
# 614/614 [==============================] - 0s 146us/sample - loss: 11.4395 - y1_output_loss: 3.9490 - y2_output_loss: 7.5087 - y1_output_root_mean_squared_error: 1.9858 - y2_output_root_mean_squared_error: 2.7379 - val_loss: 30.9332 - val_y1_output_loss: 9.6249 - val_y2_output_loss: 21.1675 - val_y1_output_root_mean_squared_error: 3.1372 - val_y2_output_root_mean_squared_error: 4.5925
# Epoch 33/500
# 614/614 [==============================] - 0s 152us/sample - loss: 11.5810 - y1_output_loss: 4.1609 - y2_output_loss: 7.3952 - y1_output_root_mean_squared_error: 2.0477 - y2_output_root_mean_squared_error: 2.7181 - val_loss: 10.1489 - val_y1_output_loss: 3.4452 - val_y2_output_loss: 6.4334 - val_y1_output_root_mean_squared_error: 1.8880 - val_y2_output_root_mean_squared_error: 2.5660
# Epoch 34/500
# 614/614 [==============================] - 0s 150us/sample - loss: 9.8257 - y1_output_loss: 3.6019 - y2_output_loss: 6.1885 - y1_output_root_mean_squared_error: 1.8999 - y2_output_root_mean_squared_error: 2.4932 - val_loss: 9.0829 - val_y1_output_loss: 3.4243 - val_y2_output_loss: 5.5614 - val_y1_output_root_mean_squared_error: 1.8769 - val_y2_output_root_mean_squared_error: 2.3580
# Epoch 35/500
# 614/614 [==============================] - 0s 158us/sample - loss: 11.4434 - y1_output_loss: 3.9898 - y2_output_loss: 7.3766 - y1_output_root_mean_squared_error: 2.0017 - y2_output_root_mean_squared_error: 2.7270 - val_loss: 8.0028 - val_y1_output_loss: 3.0348 - val_y2_output_loss: 4.9013 - val_y1_output_root_mean_squared_error: 1.7725 - val_y2_output_root_mean_squared_error: 2.2048
# Epoch 36/500
# 614/614 [==============================] - 0s 149us/sample - loss: 10.2077 - y1_output_loss: 3.7229 - y2_output_loss: 6.4657 - y1_output_root_mean_squared_error: 1.9285 - y2_output_root_mean_squared_error: 2.5473 - val_loss: 15.2761 - val_y1_output_loss: 7.2633 - val_y2_output_loss: 8.0318 - val_y1_output_root_mean_squared_error: 2.7247 - val_y2_output_root_mean_squared_error: 2.8021
# Epoch 37/500
# 614/614 [==============================] - 0s 155us/sample - loss: 8.8021 - y1_output_loss: 3.2323 - y2_output_loss: 5.5323 - y1_output_root_mean_squared_error: 1.7948 - y2_output_root_mean_squared_error: 2.3623 - val_loss: 9.0232 - val_y1_output_loss: 3.0687 - val_y2_output_loss: 5.7493 - val_y1_output_root_mean_squared_error: 1.7842 - val_y2_output_root_mean_squared_error: 2.4166
# Epoch 38/500
# 614/614 [==============================] - 0s 152us/sample - loss: 8.7532 - y1_output_loss: 3.1915 - y2_output_loss: 5.7596 - y1_output_root_mean_squared_error: 1.7619 - y2_output_root_mean_squared_error: 2.3768 - val_loss: 25.1357 - val_y1_output_loss: 6.0088 - val_y2_output_loss: 18.3415 - val_y1_output_root_mean_squared_error: 2.4921 - val_y2_output_root_mean_squared_error: 4.3503
# Epoch 39/500
# 614/614 [==============================] - 0s 156us/sample - loss: 10.3879 - y1_output_loss: 3.6580 - y2_output_loss: 6.6911 - y1_output_root_mean_squared_error: 1.9178 - y2_output_root_mean_squared_error: 2.5903 - val_loss: 9.9796 - val_y1_output_loss: 2.8009 - val_y2_output_loss: 6.8545 - val_y1_output_root_mean_squared_error: 1.7020 - val_y2_output_root_mean_squared_error: 2.6614
# Epoch 40/500
# 614/614 [==============================] - 0s 152us/sample - loss: 8.5127 - y1_output_loss: 2.8517 - y2_output_loss: 5.6132 - y1_output_root_mean_squared_error: 1.6946 - y2_output_root_mean_squared_error: 2.3751 - val_loss: 13.9922 - val_y1_output_loss: 4.8638 - val_y2_output_loss: 9.0654 - val_y1_output_root_mean_squared_error: 2.2400 - val_y2_output_root_mean_squared_error: 2.9957
# Epoch 41/500
# 614/614 [==============================] - 0s 157us/sample - loss: 9.3020 - y1_output_loss: 3.1158 - y2_output_loss: 6.1150 - y1_output_root_mean_squared_error: 1.7715 - y2_output_root_mean_squared_error: 2.4827 - val_loss: 7.7601 - val_y1_output_loss: 3.0292 - val_y2_output_loss: 4.7586 - val_y1_output_root_mean_squared_error: 1.7643 - val_y2_output_root_mean_squared_error: 2.1558
# Epoch 42/500
# 614/614 [==============================] - 0s 160us/sample - loss: 8.9698 - y1_output_loss: 3.0661 - y2_output_loss: 6.0433 - y1_output_root_mean_squared_error: 1.7382 - y2_output_root_mean_squared_error: 2.4390 - val_loss: 28.6951 - val_y1_output_loss: 9.4923 - val_y2_output_loss: 18.7782 - val_y1_output_root_mean_squared_error: 3.1328 - val_y2_output_root_mean_squared_error: 4.3452
# Epoch 43/500
# 614/614 [==============================] - 0s 149us/sample - loss: 9.5053 - y1_output_loss: 3.0118 - y2_output_loss: 6.4896 - y1_output_root_mean_squared_error: 1.7425 - y2_output_root_mean_squared_error: 2.5434 - val_loss: 14.0219 - val_y1_output_loss: 2.8962 - val_y2_output_loss: 10.6616 - val_y1_output_root_mean_squared_error: 1.7283 - val_y2_output_root_mean_squared_error: 3.3219
# Epoch 44/500
# 614/614 [==============================] - 0s 153us/sample - loss: 7.5903 - y1_output_loss: 2.6006 - y2_output_loss: 4.9557 - y1_output_root_mean_squared_error: 1.6181 - y2_output_root_mean_squared_error: 2.2298 - val_loss: 13.1522 - val_y1_output_loss: 2.5481 - val_y2_output_loss: 10.1516 - val_y1_output_root_mean_squared_error: 1.6231 - val_y2_output_root_mean_squared_error: 3.2431
# Epoch 45/500
# 614/614 [==============================] - 0s 154us/sample - loss: 7.7275 - y1_output_loss: 2.7006 - y2_output_loss: 4.9734 - y1_output_root_mean_squared_error: 1.6461 - y2_output_root_mean_squared_error: 2.2401 - val_loss: 6.4318 - val_y1_output_loss: 2.0088 - val_y2_output_loss: 4.3234 - val_y1_output_root_mean_squared_error: 1.4436 - val_y2_output_root_mean_squared_error: 2.0851
# Epoch 46/500
# 614/614 [==============================] - 0s 153us/sample - loss: 8.2126 - y1_output_loss: 2.5060 - y2_output_loss: 5.6350 - y1_output_root_mean_squared_error: 1.5895 - y2_output_root_mean_squared_error: 2.3845 - val_loss: 7.1434 - val_y1_output_loss: 2.2021 - val_y2_output_loss: 4.8098 - val_y1_output_root_mean_squared_error: 1.5101 - val_y2_output_root_mean_squared_error: 2.2052
# Epoch 47/500
# 614/614 [==============================] - 0s 167us/sample - loss: 7.6613 - y1_output_loss: 2.7101 - y2_output_loss: 4.9858 - y1_output_root_mean_squared_error: 1.6335 - y2_output_root_mean_squared_error: 2.2345 - val_loss: 9.3888 - val_y1_output_loss: 2.8707 - val_y2_output_loss: 6.2676 - val_y1_output_root_mean_squared_error: 1.7257 - val_y2_output_root_mean_squared_error: 2.5320
# Epoch 48/500
# 614/614 [==============================] - 0s 153us/sample - loss: 7.7623 - y1_output_loss: 2.5797 - y2_output_loss: 5.2031 - y1_output_root_mean_squared_error: 1.5965 - y2_output_root_mean_squared_error: 2.2833 - val_loss: 7.0899 - val_y1_output_loss: 2.4841 - val_y2_output_loss: 4.5597 - val_y1_output_root_mean_squared_error: 1.6035 - val_y2_output_root_mean_squared_error: 2.1257
# Epoch 49/500
# 614/614 [==============================] - 0s 144us/sample - loss: 7.1466 - y1_output_loss: 2.3601 - y2_output_loss: 4.7967 - y1_output_root_mean_squared_error: 1.5308 - y2_output_root_mean_squared_error: 2.1916 - val_loss: 8.6458 - val_y1_output_loss: 2.6437 - val_y2_output_loss: 5.7473 - val_y1_output_root_mean_squared_error: 1.6506 - val_y2_output_root_mean_squared_error: 2.4334
# Epoch 50/500
# 614/614 [==============================] - 0s 154us/sample - loss: 9.0526 - y1_output_loss: 2.8798 - y2_output_loss: 6.1006 - y1_output_root_mean_squared_error: 1.7029 - y2_output_root_mean_squared_error: 2.4805 - val_loss: 11.6877 - val_y1_output_loss: 4.2433 - val_y2_output_loss: 7.4292 - val_y1_output_root_mean_squared_error: 2.0892 - val_y2_output_root_mean_squared_error: 2.7061
# Epoch 51/500
# 614/614 [==============================] - 0s 153us/sample - loss: 7.9193 - y1_output_loss: 2.3976 - y2_output_loss: 5.4983 - y1_output_root_mean_squared_error: 1.5487 - y2_output_root_mean_squared_error: 2.3496 - val_loss: 7.9037 - val_y1_output_loss: 3.1315 - val_y2_output_loss: 4.8010 - val_y1_output_root_mean_squared_error: 1.7940 - val_y2_output_root_mean_squared_error: 2.1645
# Epoch 52/500
# 614/614 [==============================] - 0s 150us/sample - loss: 6.8210 - y1_output_loss: 2.2365 - y2_output_loss: 4.6145 - y1_output_root_mean_squared_error: 1.4889 - y2_output_root_mean_squared_error: 2.1457 - val_loss: 7.0176 - val_y1_output_loss: 2.3286 - val_y2_output_loss: 4.6046 - val_y1_output_root_mean_squared_error: 1.5477 - val_y2_output_root_mean_squared_error: 2.1500
# Epoch 53/500
# 614/614 [==============================] - 0s 158us/sample - loss: 6.8798 - y1_output_loss: 2.2282 - y2_output_loss: 4.6888 - y1_output_root_mean_squared_error: 1.4856 - y2_output_root_mean_squared_error: 2.1616 - val_loss: 8.6630 - val_y1_output_loss: 3.1204 - val_y2_output_loss: 5.5341 - val_y1_output_root_mean_squared_error: 1.7955 - val_y2_output_root_mean_squared_error: 2.3322
# Epoch 54/500
# 614/614 [==============================] - 0s 151us/sample - loss: 6.2837 - y1_output_loss: 1.9111 - y2_output_loss: 4.3313 - y1_output_root_mean_squared_error: 1.3864 - y2_output_root_mean_squared_error: 2.0885 - val_loss: 6.8217 - val_y1_output_loss: 2.3306 - val_y2_output_loss: 4.4242 - val_y1_output_root_mean_squared_error: 1.5536 - val_y2_output_root_mean_squared_error: 2.0995
# Epoch 55/500
# 614/614 [==============================] - 0s 158us/sample - loss: 7.7156 - y1_output_loss: 2.5456 - y2_output_loss: 5.1249 - y1_output_root_mean_squared_error: 1.5965 - y2_output_root_mean_squared_error: 2.2731 - val_loss: 6.4300 - val_y1_output_loss: 2.1541 - val_y2_output_loss: 4.2147 - val_y1_output_root_mean_squared_error: 1.4911 - val_y2_output_root_mean_squared_error: 2.0510
# Epoch 56/500
# 614/614 [==============================] - 0s 156us/sample - loss: 9.3292 - y1_output_loss: 2.8597 - y2_output_loss: 6.4139 - y1_output_root_mean_squared_error: 1.6968 - y2_output_root_mean_squared_error: 2.5397 - val_loss: 6.1610 - val_y1_output_loss: 2.1398 - val_y2_output_loss: 3.9302 - val_y1_output_root_mean_squared_error: 1.4858 - val_y2_output_root_mean_squared_error: 1.9883
# Epoch 57/500
# 614/614 [==============================] - 0s 143us/sample - loss: 5.5786 - y1_output_loss: 1.7445 - y2_output_loss: 4.0111 - y1_output_root_mean_squared_error: 1.3141 - y2_output_root_mean_squared_error: 1.9626 - val_loss: 28.1361 - val_y1_output_loss: 3.2980 - val_y2_output_loss: 24.1397 - val_y1_output_root_mean_squared_error: 1.8253 - val_y2_output_root_mean_squared_error: 4.9804
# Epoch 58/500
# 614/614 [==============================] - 0s 152us/sample - loss: 7.6022 - y1_output_loss: 2.3362 - y2_output_loss: 5.3321 - y1_output_root_mean_squared_error: 1.5172 - y2_output_root_mean_squared_error: 2.3022 - val_loss: 5.3738 - val_y1_output_loss: 1.6397 - val_y2_output_loss: 3.6696 - val_y1_output_root_mean_squared_error: 1.2995 - val_y2_output_root_mean_squared_error: 1.9196
# Epoch 59/500
# 614/614 [==============================] - 0s 154us/sample - loss: 6.6542 - y1_output_loss: 2.0093 - y2_output_loss: 4.6679 - y1_output_root_mean_squared_error: 1.4115 - y2_output_root_mean_squared_error: 2.1591 - val_loss: 5.3309 - val_y1_output_loss: 1.5435 - val_y2_output_loss: 3.8167 - val_y1_output_root_mean_squared_error: 1.2646 - val_y2_output_root_mean_squared_error: 1.9318
# Epoch 60/500
# 614/614 [==============================] - 0s 153us/sample - loss: 5.6130 - y1_output_loss: 1.7099 - y2_output_loss: 3.9091 - y1_output_root_mean_squared_error: 1.2989 - y2_output_root_mean_squared_error: 1.9814 - val_loss: 6.6876 - val_y1_output_loss: 1.9693 - val_y2_output_loss: 4.5647 - val_y1_output_root_mean_squared_error: 1.4213 - val_y2_output_root_mean_squared_error: 2.1605
# Epoch 61/500
# 614/614 [==============================] - 0s 154us/sample - loss: 5.8000 - y1_output_loss: 1.7197 - y2_output_loss: 4.1322 - y1_output_root_mean_squared_error: 1.3136 - y2_output_root_mean_squared_error: 2.0185 - val_loss: 5.4665 - val_y1_output_loss: 1.6487 - val_y2_output_loss: 3.7250 - val_y1_output_root_mean_squared_error: 1.3083 - val_y2_output_root_mean_squared_error: 1.9377
# Epoch 62/500
# 614/614 [==============================] - 0s 150us/sample - loss: 5.7693 - y1_output_loss: 1.7300 - y2_output_loss: 4.0645 - y1_output_root_mean_squared_error: 1.3178 - y2_output_root_mean_squared_error: 2.0082 - val_loss: 6.1820 - val_y1_output_loss: 2.1609 - val_y2_output_loss: 3.9693 - val_y1_output_root_mean_squared_error: 1.4953 - val_y2_output_root_mean_squared_error: 1.9865
# Epoch 63/500
# 614/614 [==============================] - 0s 156us/sample - loss: 5.3407 - y1_output_loss: 1.6610 - y2_output_loss: 3.7761 - y1_output_root_mean_squared_error: 1.2848 - y2_output_root_mean_squared_error: 1.9209 - val_loss: 19.1599 - val_y1_output_loss: 3.5676 - val_y2_output_loss: 15.0681 - val_y1_output_root_mean_squared_error: 1.9032 - val_y2_output_root_mean_squared_error: 3.9418
# Epoch 64/500
# 614/614 [==============================] - 0s 156us/sample - loss: 5.5883 - y1_output_loss: 1.7122 - y2_output_loss: 3.9161 - y1_output_root_mean_squared_error: 1.3066 - y2_output_root_mean_squared_error: 1.9701 - val_loss: 10.3908 - val_y1_output_loss: 2.1572 - val_y2_output_loss: 7.9131 - val_y1_output_root_mean_squared_error: 1.4915 - val_y2_output_root_mean_squared_error: 2.8577
# Epoch 65/500
# 614/614 [==============================] - 0s 162us/sample - loss: 5.6697 - y1_output_loss: 1.5995 - y2_output_loss: 4.0352 - y1_output_root_mean_squared_error: 1.2678 - y2_output_root_mean_squared_error: 2.0156 - val_loss: 7.1093 - val_y1_output_loss: 2.9012 - val_y2_output_loss: 4.1482 - val_y1_output_root_mean_squared_error: 1.7288 - val_y2_output_root_mean_squared_error: 2.0299
# Epoch 66/500
# 614/614 [==============================] - 0s 151us/sample - loss: 5.8219 - y1_output_loss: 1.6435 - y2_output_loss: 4.1490 - y1_output_root_mean_squared_error: 1.2836 - y2_output_root_mean_squared_error: 2.0431 - val_loss: 10.2404 - val_y1_output_loss: 2.2995 - val_y2_output_loss: 8.0656 - val_y1_output_root_mean_squared_error: 1.5354 - val_y2_output_root_mean_squared_error: 2.8076
# Epoch 67/500
# 614/614 [==============================] - 0s 153us/sample - loss: 5.0900 - y1_output_loss: 1.5276 - y2_output_loss: 3.5925 - y1_output_root_mean_squared_error: 1.2334 - y2_output_root_mean_squared_error: 1.8891 - val_loss: 6.2162 - val_y1_output_loss: 2.2806 - val_y2_output_loss: 3.9871 - val_y1_output_root_mean_squared_error: 1.5302 - val_y2_output_root_mean_squared_error: 1.9684
# Epoch 68/500
# 614/614 [==============================] - 0s 159us/sample - loss: 5.7278 - y1_output_loss: 1.6446 - y2_output_loss: 4.0560 - y1_output_root_mean_squared_error: 1.2779 - y2_output_root_mean_squared_error: 2.0236 - val_loss: 5.8444 - val_y1_output_loss: 1.2810 - val_y2_output_loss: 4.4000 - val_y1_output_root_mean_squared_error: 1.1491 - val_y2_output_root_mean_squared_error: 2.1270
# Epoch 69/500
# 614/614 [==============================] - 0s 158us/sample - loss: 5.2649 - y1_output_loss: 1.3896 - y2_output_loss: 3.8378 - y1_output_root_mean_squared_error: 1.1793 - y2_output_root_mean_squared_error: 1.9683 - val_loss: 5.5796 - val_y1_output_loss: 1.4314 - val_y2_output_loss: 4.1209 - val_y1_output_root_mean_squared_error: 1.2140 - val_y2_output_root_mean_squared_error: 2.0263
# Epoch 70/500
# 614/614 [==============================] - 0s 161us/sample - loss: 5.8103 - y1_output_loss: 1.6103 - y2_output_loss: 4.1661 - y1_output_root_mean_squared_error: 1.2722 - y2_output_root_mean_squared_error: 2.0474 - val_loss: 5.6848 - val_y1_output_loss: 1.6163 - val_y2_output_loss: 3.9491 - val_y1_output_root_mean_squared_error: 1.2944 - val_y2_output_root_mean_squared_error: 2.0023
# Epoch 71/500
# 614/614 [==============================] - 0s 159us/sample - loss: 4.2077 - y1_output_loss: 1.2247 - y2_output_loss: 3.0190 - y1_output_root_mean_squared_error: 1.1078 - y2_output_root_mean_squared_error: 1.7264 - val_loss: 4.3735 - val_y1_output_loss: 1.2759 - val_y2_output_loss: 3.0904 - val_y1_output_root_mean_squared_error: 1.1452 - val_y2_output_root_mean_squared_error: 1.7499
# Epoch 72/500
# 614/614 [==============================] - 0s 157us/sample - loss: 5.0628 - y1_output_loss: 1.3163 - y2_output_loss: 3.7165 - y1_output_root_mean_squared_error: 1.1499 - y2_output_root_mean_squared_error: 1.9341 - val_loss: 5.4299 - val_y1_output_loss: 1.2101 - val_y2_output_loss: 4.0987 - val_y1_output_root_mean_squared_error: 1.1106 - val_y2_output_root_mean_squared_error: 2.0485
# Epoch 73/500
# 614/614 [==============================] - 0s 154us/sample - loss: 4.3548 - y1_output_loss: 1.2146 - y2_output_loss: 3.1530 - y1_output_root_mean_squared_error: 1.0969 - y2_output_root_mean_squared_error: 1.7753 - val_loss: 5.7912 - val_y1_output_loss: 1.2205 - val_y2_output_loss: 4.3967 - val_y1_output_root_mean_squared_error: 1.1238 - val_y2_output_root_mean_squared_error: 2.1280
# Epoch 74/500
# 614/614 [==============================] - 0s 149us/sample - loss: 4.7924 - y1_output_loss: 1.2211 - y2_output_loss: 3.5298 - y1_output_root_mean_squared_error: 1.1099 - y2_output_root_mean_squared_error: 1.8869 - val_loss: 5.1190 - val_y1_output_loss: 1.5218 - val_y2_output_loss: 3.6037 - val_y1_output_root_mean_squared_error: 1.2540 - val_y2_output_root_mean_squared_error: 1.8832
# Epoch 75/500
# 614/614 [==============================] - 0s 159us/sample - loss: 3.7993 - y1_output_loss: 0.9932 - y2_output_loss: 2.8218 - y1_output_root_mean_squared_error: 0.9960 - y2_output_root_mean_squared_error: 1.6755 - val_loss: 14.3828 - val_y1_output_loss: 2.7730 - val_y2_output_loss: 11.2055 - val_y1_output_root_mean_squared_error: 1.6891 - val_y2_output_root_mean_squared_error: 3.3956
# Epoch 76/500
# 614/614 [==============================] - 0s 156us/sample - loss: 4.1817 - y1_output_loss: 1.0777 - y2_output_loss: 3.0742 - y1_output_root_mean_squared_error: 1.0396 - y2_output_root_mean_squared_error: 1.7609 - val_loss: 4.3965 - val_y1_output_loss: 1.1742 - val_y2_output_loss: 3.1131 - val_y1_output_root_mean_squared_error: 1.0969 - val_y2_output_root_mean_squared_error: 1.7870
# Epoch 77/500
# 614/614 [==============================] - 0s 163us/sample - loss: 5.1788 - y1_output_loss: 1.1742 - y2_output_loss: 3.9962 - y1_output_root_mean_squared_error: 1.0829 - y2_output_root_mean_squared_error: 2.0015 - val_loss: 4.2797 - val_y1_output_loss: 1.2946 - val_y2_output_loss: 2.9685 - val_y1_output_root_mean_squared_error: 1.1576 - val_y2_output_root_mean_squared_error: 1.7146
# Epoch 78/500
# 614/614 [==============================] - 0s 147us/sample - loss: 4.5985 - y1_output_loss: 1.0638 - y2_output_loss: 3.5162 - y1_output_root_mean_squared_error: 1.0352 - y2_output_root_mean_squared_error: 1.8780 - val_loss: 4.4817 - val_y1_output_loss: 0.7414 - val_y2_output_loss: 3.6134 - val_y1_output_root_mean_squared_error: 0.8729 - val_y2_output_root_mean_squared_error: 1.9286
# Epoch 79/500
# 614/614 [==============================] - 0s 153us/sample - loss: 4.2382 - y1_output_loss: 1.1897 - y2_output_loss: 3.0196 - y1_output_root_mean_squared_error: 1.0956 - y2_output_root_mean_squared_error: 1.7430 - val_loss: 9.7437 - val_y1_output_loss: 0.9772 - val_y2_output_loss: 8.4630 - val_y1_output_root_mean_squared_error: 0.9848 - val_y2_output_root_mean_squared_error: 2.9621
# Epoch 80/500
# 614/614 [==============================] - 0s 155us/sample - loss: 4.0914 - y1_output_loss: 1.0617 - y2_output_loss: 3.0284 - y1_output_root_mean_squared_error: 1.0315 - y2_output_root_mean_squared_error: 1.7399 - val_loss: 4.7951 - val_y1_output_loss: 0.9805 - val_y2_output_loss: 3.6959 - val_y1_output_root_mean_squared_error: 0.9984 - val_y2_output_root_mean_squared_error: 1.9489
# Epoch 81/500
# 614/614 [==============================] - 0s 153us/sample - loss: 3.7603 - y1_output_loss: 0.9551 - y2_output_loss: 2.8206 - y1_output_root_mean_squared_error: 0.9803 - y2_output_root_mean_squared_error: 1.6731 - val_loss: 4.6083 - val_y1_output_loss: 0.8709 - val_y2_output_loss: 3.6160 - val_y1_output_root_mean_squared_error: 0.9288 - val_y2_output_root_mean_squared_error: 1.9354
# Epoch 82/500
# 614/614 [==============================] - 0s 157us/sample - loss: 5.5711 - y1_output_loss: 1.3293 - y2_output_loss: 4.1921 - y1_output_root_mean_squared_error: 1.1575 - y2_output_root_mean_squared_error: 2.0570 - val_loss: 3.3712 - val_y1_output_loss: 0.6897 - val_y2_output_loss: 2.6681 - val_y1_output_root_mean_squared_error: 0.8430 - val_y2_output_root_mean_squared_error: 1.6311
# Epoch 83/500
# 614/614 [==============================] - 0s 148us/sample - loss: 5.1354 - y1_output_loss: 1.2545 - y2_output_loss: 3.8422 - y1_output_root_mean_squared_error: 1.1222 - y2_output_root_mean_squared_error: 1.9688 - val_loss: 3.6748 - val_y1_output_loss: 0.8355 - val_y2_output_loss: 2.7785 - val_y1_output_root_mean_squared_error: 0.9301 - val_y2_output_root_mean_squared_error: 1.6762
# Epoch 84/500
# 614/614 [==============================] - 0s 155us/sample - loss: 6.8061 - y1_output_loss: 1.9317 - y2_output_loss: 4.8205 - y1_output_root_mean_squared_error: 1.3927 - y2_output_root_mean_squared_error: 2.2060 - val_loss: 4.1762 - val_y1_output_loss: 1.3227 - val_y2_output_loss: 2.7786 - val_y1_output_root_mean_squared_error: 1.1709 - val_y2_output_root_mean_squared_error: 1.6749
# Epoch 85/500
# 614/614 [==============================] - 0s 153us/sample - loss: 3.0939 - y1_output_loss: 0.7788 - y2_output_loss: 2.3039 - y1_output_root_mean_squared_error: 0.8818 - y2_output_root_mean_squared_error: 1.5220 - val_loss: 4.8247 - val_y1_output_loss: 1.6066 - val_y2_output_loss: 3.2220 - val_y1_output_root_mean_squared_error: 1.2718 - val_y2_output_root_mean_squared_error: 1.7909
# Epoch 86/500
# 614/614 [==============================] - 0s 155us/sample - loss: 3.6325 - y1_output_loss: 0.8782 - y2_output_loss: 2.7207 - y1_output_root_mean_squared_error: 0.9411 - y2_output_root_mean_squared_error: 1.6574 - val_loss: 3.2381 - val_y1_output_loss: 0.6915 - val_y2_output_loss: 2.4907 - val_y1_output_root_mean_squared_error: 0.8455 - val_y2_output_root_mean_squared_error: 1.5885
# Epoch 87/500
# 614/614 [==============================] - 0s 154us/sample - loss: 3.4231 - y1_output_loss: 0.7524 - y2_output_loss: 2.6816 - y1_output_root_mean_squared_error: 0.8705 - y2_output_root_mean_squared_error: 1.6326 - val_loss: 5.3922 - val_y1_output_loss: 0.7100 - val_y2_output_loss: 4.5299 - val_y1_output_root_mean_squared_error: 0.8394 - val_y2_output_root_mean_squared_error: 2.1651
# Epoch 88/500
# 614/614 [==============================] - 0s 158us/sample - loss: 3.0936 - y1_output_loss: 0.7783 - y2_output_loss: 2.3307 - y1_output_root_mean_squared_error: 0.8722 - y2_output_root_mean_squared_error: 1.5274 - val_loss: 7.0060 - val_y1_output_loss: 2.0746 - val_y2_output_loss: 4.8509 - val_y1_output_root_mean_squared_error: 1.4664 - val_y2_output_root_mean_squared_error: 2.2035
# Epoch 89/500
# 614/614 [==============================] - 0s 149us/sample - loss: 3.4190 - y1_output_loss: 0.8067 - y2_output_loss: 2.5947 - y1_output_root_mean_squared_error: 0.9008 - y2_output_root_mean_squared_error: 1.6148 - val_loss: 3.4489 - val_y1_output_loss: 0.6896 - val_y2_output_loss: 2.7066 - val_y1_output_root_mean_squared_error: 0.8380 - val_y2_output_root_mean_squared_error: 1.6573
# Epoch 90/500
# 614/614 [==============================] - 0s 151us/sample - loss: 4.0519 - y1_output_loss: 0.9326 - y2_output_loss: 3.1071 - y1_output_root_mean_squared_error: 0.9646 - y2_output_root_mean_squared_error: 1.7668 - val_loss: 5.8024 - val_y1_output_loss: 1.1896 - val_y2_output_loss: 4.6322 - val_y1_output_root_mean_squared_error: 1.1083 - val_y2_output_root_mean_squared_error: 2.1387
# Epoch 91/500
# 614/614 [==============================] - 0s 151us/sample - loss: 2.6792 - y1_output_loss: 0.6644 - y2_output_loss: 2.0030 - y1_output_root_mean_squared_error: 0.8121 - y2_output_root_mean_squared_error: 1.4211 - val_loss: 2.9150 - val_y1_output_loss: 0.4716 - val_y2_output_loss: 2.4315 - val_y1_output_root_mean_squared_error: 0.6916 - val_y2_output_root_mean_squared_error: 1.5610
# Epoch 92/500
# 614/614 [==============================] - 0s 154us/sample - loss: 3.5471 - y1_output_loss: 0.8840 - y2_output_loss: 2.6486 - y1_output_root_mean_squared_error: 0.9367 - y2_output_root_mean_squared_error: 1.6339 - val_loss: 5.3532 - val_y1_output_loss: 0.9400 - val_y2_output_loss: 4.4008 - val_y1_output_root_mean_squared_error: 0.9854 - val_y2_output_root_mean_squared_error: 2.0934
# Epoch 93/500
# 614/614 [==============================] - 0s 155us/sample - loss: 3.3652 - y1_output_loss: 0.7350 - y2_output_loss: 2.6383 - y1_output_root_mean_squared_error: 0.8545 - y2_output_root_mean_squared_error: 1.6233 - val_loss: 6.2241 - val_y1_output_loss: 1.4170 - val_y2_output_loss: 4.6374 - val_y1_output_root_mean_squared_error: 1.2073 - val_y2_output_root_mean_squared_error: 2.1832
# Epoch 94/500
# 614/614 [==============================] - 0s 157us/sample - loss: 2.9436 - y1_output_loss: 0.6807 - y2_output_loss: 2.3179 - y1_output_root_mean_squared_error: 0.8279 - y2_output_root_mean_squared_error: 1.5027 - val_loss: 5.8397 - val_y1_output_loss: 1.0802 - val_y2_output_loss: 4.7158 - val_y1_output_root_mean_squared_error: 1.0580 - val_y2_output_root_mean_squared_error: 2.1727
# Epoch 95/500
# 614/614 [==============================] - 0s 154us/sample - loss: 2.9624 - y1_output_loss: 0.6838 - y2_output_loss: 2.2865 - y1_output_root_mean_squared_error: 0.8281 - y2_output_root_mean_squared_error: 1.5088 - val_loss: 4.3707 - val_y1_output_loss: 0.6986 - val_y2_output_loss: 3.5554 - val_y1_output_root_mean_squared_error: 0.8361 - val_y2_output_root_mean_squared_error: 1.9162
# Epoch 96/500
# 614/614 [==============================] - 0s 155us/sample - loss: 2.5784 - y1_output_loss: 0.6296 - y2_output_loss: 1.9350 - y1_output_root_mean_squared_error: 0.7961 - y2_output_root_mean_squared_error: 1.3945 - val_loss: 2.9806 - val_y1_output_loss: 0.4821 - val_y2_output_loss: 2.4474 - val_y1_output_root_mean_squared_error: 0.7047 - val_y2_output_root_mean_squared_error: 1.5761
# Epoch 97/500
# 614/614 [==============================] - 0s 171us/sample - loss: 2.9820 - y1_output_loss: 0.7166 - y2_output_loss: 2.2488 - y1_output_root_mean_squared_error: 0.8462 - y2_output_root_mean_squared_error: 1.5053 - val_loss: 3.2370 - val_y1_output_loss: 0.7632 - val_y2_output_loss: 2.4460 - val_y1_output_root_mean_squared_error: 0.8808 - val_y2_output_root_mean_squared_error: 1.5688
# Epoch 98/500
# 614/614 [==============================] - 0s 188us/sample - loss: 3.3073 - y1_output_loss: 0.8773 - y2_output_loss: 2.4288 - y1_output_root_mean_squared_error: 0.9342 - y2_output_root_mean_squared_error: 1.5603 - val_loss: 3.6593 - val_y1_output_loss: 0.6082 - val_y2_output_loss: 2.9541 - val_y1_output_root_mean_squared_error: 0.7916 - val_y2_output_root_mean_squared_error: 1.7415
# Epoch 99/500
# 614/614 [==============================] - 0s 171us/sample - loss: 2.6068 - y1_output_loss: 0.6504 - y2_output_loss: 1.9550 - y1_output_root_mean_squared_error: 0.8043 - y2_output_root_mean_squared_error: 1.4000 - val_loss: 3.7508 - val_y1_output_loss: 0.8680 - val_y2_output_loss: 2.8856 - val_y1_output_root_mean_squared_error: 0.9443 - val_y2_output_root_mean_squared_error: 1.6909
# Epoch 100/500
# 614/614 [==============================] - 0s 162us/sample - loss: 3.4133 - y1_output_loss: 0.7704 - y2_output_loss: 2.7307 - y1_output_root_mean_squared_error: 0.8712 - y2_output_root_mean_squared_error: 1.6292 - val_loss: 8.6961 - val_y1_output_loss: 2.5407 - val_y2_output_loss: 6.1320 - val_y1_output_root_mean_squared_error: 1.6195 - val_y2_output_root_mean_squared_error: 2.4644
# Epoch 101/500
# 614/614 [==============================] - 0s 157us/sample - loss: 3.0292 - y1_output_loss: 0.6922 - y2_output_loss: 2.3243 - y1_output_root_mean_squared_error: 0.8352 - y2_output_root_mean_squared_error: 1.5270 - val_loss: 3.1525 - val_y1_output_loss: 0.6043 - val_y2_output_loss: 2.5460 - val_y1_output_root_mean_squared_error: 0.7880 - val_y2_output_root_mean_squared_error: 1.5911
# Epoch 102/500
# 614/614 [==============================] - 0s 167us/sample - loss: 2.6467 - y1_output_loss: 0.5752 - y2_output_loss: 2.0579 - y1_output_root_mean_squared_error: 0.7594 - y2_output_root_mean_squared_error: 1.4388 - val_loss: 3.3108 - val_y1_output_loss: 0.7265 - val_y2_output_loss: 2.5282 - val_y1_output_root_mean_squared_error: 0.8536 - val_y2_output_root_mean_squared_error: 1.6069
# Epoch 103/500
# 614/614 [==============================] - 0s 155us/sample - loss: 2.7795 - y1_output_loss: 0.7043 - y2_output_loss: 2.1050 - y1_output_root_mean_squared_error: 0.8301 - y2_output_root_mean_squared_error: 1.4458 - val_loss: 9.1341 - val_y1_output_loss: 1.6555 - val_y2_output_loss: 7.2056 - val_y1_output_root_mean_squared_error: 1.2881 - val_y2_output_root_mean_squared_error: 2.7340
# Epoch 104/500
# 614/614 [==============================] - 0s 164us/sample - loss: 2.6041 - y1_output_loss: 0.5746 - y2_output_loss: 2.0276 - y1_output_root_mean_squared_error: 0.7597 - y2_output_root_mean_squared_error: 1.4237 - val_loss: 6.2587 - val_y1_output_loss: 0.6878 - val_y2_output_loss: 5.3685 - val_y1_output_root_mean_squared_error: 0.8354 - val_y2_output_root_mean_squared_error: 2.3581
# Epoch 105/500
# 614/614 [==============================] - 0s 164us/sample - loss: 2.7721 - y1_output_loss: 0.6069 - y2_output_loss: 2.1479 - y1_output_root_mean_squared_error: 0.7799 - y2_output_root_mean_squared_error: 1.4710 - val_loss: 3.0715 - val_y1_output_loss: 0.6070 - val_y2_output_loss: 2.4121 - val_y1_output_root_mean_squared_error: 0.7877 - val_y2_output_root_mean_squared_error: 1.5655
# Epoch 106/500
# 614/614 [==============================] - 0s 162us/sample - loss: 2.4156 - y1_output_loss: 0.5649 - y2_output_loss: 1.8299 - y1_output_root_mean_squared_error: 0.7551 - y2_output_root_mean_squared_error: 1.3585 - val_loss: 3.3377 - val_y1_output_loss: 0.5439 - val_y2_output_loss: 2.7107 - val_y1_output_root_mean_squared_error: 0.7468 - val_y2_output_root_mean_squared_error: 1.6673
# Epoch 107/500
# 614/614 [==============================] - 0s 158us/sample - loss: 2.9275 - y1_output_loss: 0.6493 - y2_output_loss: 2.2616 - y1_output_root_mean_squared_error: 0.8058 - y2_output_root_mean_squared_error: 1.5094 - val_loss: 3.9639 - val_y1_output_loss: 0.8201 - val_y2_output_loss: 3.2184 - val_y1_output_root_mean_squared_error: 0.9209 - val_y2_output_root_mean_squared_error: 1.7652
# Epoch 108/500
# 614/614 [==============================] - 0s 163us/sample - loss: 2.3511 - y1_output_loss: 0.5357 - y2_output_loss: 1.8273 - y1_output_root_mean_squared_error: 0.7312 - y2_output_root_mean_squared_error: 1.3477 - val_loss: 5.1285 - val_y1_output_loss: 1.1051 - val_y2_output_loss: 4.0181 - val_y1_output_root_mean_squared_error: 1.0711 - val_y2_output_root_mean_squared_error: 1.9953
# Epoch 109/500
# 614/614 [==============================] - 0s 162us/sample - loss: 3.5422 - y1_output_loss: 0.7669 - y2_output_loss: 2.7526 - y1_output_root_mean_squared_error: 0.8758 - y2_output_root_mean_squared_error: 1.6659 - val_loss: 5.7680 - val_y1_output_loss: 1.9098 - val_y2_output_loss: 3.7394 - val_y1_output_root_mean_squared_error: 1.4050 - val_y2_output_root_mean_squared_error: 1.9478
# Epoch 110/500
# 614/614 [==============================] - 0s 162us/sample - loss: 2.7844 - y1_output_loss: 0.5608 - y2_output_loss: 2.2078 - y1_output_root_mean_squared_error: 0.7496 - y2_output_root_mean_squared_error: 1.4908 - val_loss: 5.4428 - val_y1_output_loss: 1.0999 - val_y2_output_loss: 4.1682 - val_y1_output_root_mean_squared_error: 1.0579 - val_y2_output_root_mean_squared_error: 2.0793
# Epoch 111/500
# 614/614 [==============================] - 0s 167us/sample - loss: 2.8534 - y1_output_loss: 0.7238 - y2_output_loss: 2.1146 - y1_output_root_mean_squared_error: 0.8521 - y2_output_root_mean_squared_error: 1.4585 - val_loss: 3.6285 - val_y1_output_loss: 1.0848 - val_y2_output_loss: 2.5154 - val_y1_output_root_mean_squared_error: 1.0575 - val_y2_output_root_mean_squared_error: 1.5844
# Epoch 112/500
# 614/614 [==============================] - 0s 154us/sample - loss: 2.5586 - y1_output_loss: 0.7612 - y2_output_loss: 1.8180 - y1_output_root_mean_squared_error: 0.8673 - y2_output_root_mean_squared_error: 1.3440 - val_loss: 3.0644 - val_y1_output_loss: 0.6568 - val_y2_output_loss: 2.3510 - val_y1_output_root_mean_squared_error: 0.8078 - val_y2_output_root_mean_squared_error: 1.5530
# Epoch 113/500
# 614/614 [==============================] - 0s 173us/sample - loss: 3.6645 - y1_output_loss: 0.7822 - y2_output_loss: 2.8733 - y1_output_root_mean_squared_error: 0.8858 - y2_output_root_mean_squared_error: 1.6970 - val_loss: 5.0626 - val_y1_output_loss: 1.6796 - val_y2_output_loss: 3.2594 - val_y1_output_root_mean_squared_error: 1.3202 - val_y2_output_root_mean_squared_error: 1.8220
# Epoch 114/500
# 614/614 [==============================] - 0s 169us/sample - loss: 2.5405 - y1_output_loss: 0.6081 - y2_output_loss: 2.0106 - y1_output_root_mean_squared_error: 0.7774 - y2_output_root_mean_squared_error: 1.3914 - val_loss: 9.3060 - val_y1_output_loss: 1.2286 - val_y2_output_loss: 8.0806 - val_y1_output_root_mean_squared_error: 1.1186 - val_y2_output_root_mean_squared_error: 2.8381
# Epoch 115/500
# 614/614 [==============================] - 0s 164us/sample - loss: 2.3833 - y1_output_loss: 0.5195 - y2_output_loss: 1.8437 - y1_output_root_mean_squared_error: 0.7229 - y2_output_root_mean_squared_error: 1.3641 - val_loss: 2.6314 - val_y1_output_loss: 0.4405 - val_y2_output_loss: 2.1281 - val_y1_output_root_mean_squared_error: 0.6646 - val_y2_output_root_mean_squared_error: 1.4797
# Epoch 116/500
# 614/614 [==============================] - 0s 160us/sample - loss: 2.1933 - y1_output_loss: 0.5703 - y2_output_loss: 1.6450 - y1_output_root_mean_squared_error: 0.7517 - y2_output_root_mean_squared_error: 1.2760 - val_loss: 4.2458 - val_y1_output_loss: 0.7091 - val_y2_output_loss: 3.4104 - val_y1_output_root_mean_squared_error: 0.8513 - val_y2_output_root_mean_squared_error: 1.8765
# Epoch 117/500
# 614/614 [==============================] - 0s 159us/sample - loss: 2.6415 - y1_output_loss: 0.6754 - y2_output_loss: 1.9632 - y1_output_root_mean_squared_error: 0.8224 - y2_output_root_mean_squared_error: 1.4018 - val_loss: 5.3035 - val_y1_output_loss: 1.9981 - val_y2_output_loss: 3.1904 - val_y1_output_root_mean_squared_error: 1.4402 - val_y2_output_root_mean_squared_error: 1.7971
# Epoch 118/500
# 614/614 [==============================] - 0s 161us/sample - loss: 2.6882 - y1_output_loss: 0.5572 - y2_output_loss: 2.1101 - y1_output_root_mean_squared_error: 0.7490 - y2_output_root_mean_squared_error: 1.4585 - val_loss: 3.2742 - val_y1_output_loss: 0.5615 - val_y2_output_loss: 2.6388 - val_y1_output_root_mean_squared_error: 0.7420 - val_y2_output_root_mean_squared_error: 1.6503
# Epoch 119/500
# 614/614 [==============================] - 0s 167us/sample - loss: 2.2495 - y1_output_loss: 0.5700 - y2_output_loss: 1.6740 - y1_output_root_mean_squared_error: 0.7564 - y2_output_root_mean_squared_error: 1.2951 - val_loss: 5.8386 - val_y1_output_loss: 0.5428 - val_y2_output_loss: 5.1061 - val_y1_output_root_mean_squared_error: 0.7336 - val_y2_output_root_mean_squared_error: 2.3023
# Epoch 120/500
# 614/614 [==============================] - 0s 163us/sample - loss: 2.7612 - y1_output_loss: 0.6305 - y2_output_loss: 2.1205 - y1_output_root_mean_squared_error: 0.7970 - y2_output_root_mean_squared_error: 1.4581 - val_loss: 5.3522 - val_y1_output_loss: 0.6479 - val_y2_output_loss: 4.5423 - val_y1_output_root_mean_squared_error: 0.7979 - val_y2_output_root_mean_squared_error: 2.1715
# Epoch 121/500
# ...
# Epoch 461/500
# 614/614 [==============================] - 0s 144us/sample - loss: 0.3963 - y1_output_loss: 0.1323 - y2_output_loss: 0.2620 - y1_output_root_mean_squared_error: 0.3648 - y2_output_root_mean_squared_error: 0.5131 - val_loss: 1.1588 - val_y1_output_loss: 0.1510 - val_y2_output_loss: 0.9676 - val_y1_output_root_mean_squared_error: 0.3951 - val_y2_output_root_mean_squared_error: 1.0014
# Epoch 462/500
# 614/614 [==============================] - 0s 145us/sample - loss: 0.3673 - y1_output_loss: 0.1182 - y2_output_loss: 0.2471 - y1_output_root_mean_squared_error: 0.3446 - y2_output_root_mean_squared_error: 0.4986 - val_loss: 0.9472 - val_y1_output_loss: 0.1646 - val_y2_output_loss: 0.7500 - val_y1_output_root_mean_squared_error: 0.4112 - val_y2_output_root_mean_squared_error: 0.8821
# Epoch 463/500
# 614/614 [==============================] - 0s 143us/sample - loss: 0.3246 - y1_output_loss: 0.1184 - y2_output_loss: 0.2044 - y1_output_root_mean_squared_error: 0.3451 - y2_output_root_mean_squared_error: 0.4533 - val_loss: 0.9868 - val_y1_output_loss: 0.1490 - val_y2_output_loss: 0.8037 - val_y1_output_root_mean_squared_error: 0.3918 - val_y2_output_root_mean_squared_error: 0.9128
# Epoch 464/500
# 614/614 [==============================] - 0s 145us/sample - loss: 0.4135 - y1_output_loss: 0.1259 - y2_output_loss: 0.2864 - y1_output_root_mean_squared_error: 0.3561 - y2_output_root_mean_squared_error: 0.5355 - val_loss: 0.8962 - val_y1_output_loss: 0.1573 - val_y2_output_loss: 0.7102 - val_y1_output_root_mean_squared_error: 0.3997 - val_y2_output_root_mean_squared_error: 0.8582
# Epoch 465/500
# 614/614 [==============================] - 0s 148us/sample - loss: 0.4657 - y1_output_loss: 0.1372 - y2_output_loss: 0.3283 - y1_output_root_mean_squared_error: 0.3687 - y2_output_root_mean_squared_error: 0.5743 - val_loss: 1.0148 - val_y1_output_loss: 0.3119 - val_y2_output_loss: 0.6734 - val_y1_output_root_mean_squared_error: 0.5687 - val_y2_output_root_mean_squared_error: 0.8315
# Epoch 466/500
# 614/614 [==============================] - 0s 144us/sample - loss: 0.5693 - y1_output_loss: 0.1428 - y2_output_loss: 0.4219 - y1_output_root_mean_squared_error: 0.3790 - y2_output_root_mean_squared_error: 0.6524 - val_loss: 0.9728 - val_y1_output_loss: 0.1286 - val_y2_output_loss: 0.8137 - val_y1_output_root_mean_squared_error: 0.3615 - val_y2_output_root_mean_squared_error: 0.9177
# Epoch 467/500
# 614/614 [==============================] - 0s 141us/sample - loss: 0.4067 - y1_output_loss: 0.1200 - y2_output_loss: 0.2842 - y1_output_root_mean_squared_error: 0.3471 - y2_output_root_mean_squared_error: 0.5350 - val_loss: 0.8958 - val_y1_output_loss: 0.1483 - val_y2_output_loss: 0.7205 - val_y1_output_root_mean_squared_error: 0.3899 - val_y2_output_root_mean_squared_error: 0.8624
# Epoch 468/500
# 614/614 [==============================] - 0s 142us/sample - loss: 0.3611 - y1_output_loss: 0.1223 - y2_output_loss: 0.2408 - y1_output_root_mean_squared_error: 0.3508 - y2_output_root_mean_squared_error: 0.4879 - val_loss: 1.1831 - val_y1_output_loss: 0.2156 - val_y2_output_loss: 0.9360 - val_y1_output_root_mean_squared_error: 0.4653 - val_y2_output_root_mean_squared_error: 0.9832
# Epoch 469/500
# 614/614 [==============================] - 0s 146us/sample - loss: 0.4343 - y1_output_loss: 0.1359 - y2_output_loss: 0.2951 - y1_output_root_mean_squared_error: 0.3703 - y2_output_root_mean_squared_error: 0.5451 - val_loss: 0.9228 - val_y1_output_loss: 0.1502 - val_y2_output_loss: 0.7424 - val_y1_output_root_mean_squared_error: 0.3915 - val_y2_output_root_mean_squared_error: 0.8772
# Epoch 470/500
# 614/614 [==============================] - 0s 150us/sample - loss: 0.4188 - y1_output_loss: 0.1271 - y2_output_loss: 0.2925 - y1_output_root_mean_squared_error: 0.3547 - y2_output_root_mean_squared_error: 0.5413 - val_loss: 0.8924 - val_y1_output_loss: 0.1305 - val_y2_output_loss: 0.7321 - val_y1_output_root_mean_squared_error: 0.3650 - val_y2_output_root_mean_squared_error: 0.8713
# Epoch 471/500
# 614/614 [==============================] - 0s 149us/sample - loss: 0.4059 - y1_output_loss: 0.1238 - y2_output_loss: 0.2786 - y1_output_root_mean_squared_error: 0.3533 - y2_output_root_mean_squared_error: 0.5302 - val_loss: 0.8968 - val_y1_output_loss: 0.1519 - val_y2_output_loss: 0.7128 - val_y1_output_root_mean_squared_error: 0.3964 - val_y2_output_root_mean_squared_error: 0.8600
# Epoch 472/500
# 614/614 [==============================] - 0s 147us/sample - loss: 0.4140 - y1_output_loss: 0.1378 - y2_output_loss: 0.2871 - y1_output_root_mean_squared_error: 0.3675 - y2_output_root_mean_squared_error: 0.5281 - val_loss: 1.3772 - val_y1_output_loss: 0.4667 - val_y2_output_loss: 0.8934 - val_y1_output_root_mean_squared_error: 0.6897 - val_y2_output_root_mean_squared_error: 0.9494
# Epoch 473/500
# 614/614 [==============================] - 0s 141us/sample - loss: 0.3415 - y1_output_loss: 0.1190 - y2_output_loss: 0.2245 - y1_output_root_mean_squared_error: 0.3456 - y2_output_root_mean_squared_error: 0.4712 - val_loss: 0.9435 - val_y1_output_loss: 0.1833 - val_y2_output_loss: 0.7391 - val_y1_output_root_mean_squared_error: 0.4294 - val_y2_output_root_mean_squared_error: 0.8712
# Epoch 474/500
# 614/614 [==============================] - 0s 147us/sample - loss: 0.6691 - y1_output_loss: 0.2184 - y2_output_loss: 0.4480 - y1_output_root_mean_squared_error: 0.4685 - y2_output_root_mean_squared_error: 0.6705 - val_loss: 1.0483 - val_y1_output_loss: 0.1536 - val_y2_output_loss: 0.8816 - val_y1_output_root_mean_squared_error: 0.3987 - val_y2_output_root_mean_squared_error: 0.9431
# Epoch 475/500
# 614/614 [==============================] - 0s 147us/sample - loss: 0.4032 - y1_output_loss: 0.1263 - y2_output_loss: 0.2811 - y1_output_root_mean_squared_error: 0.3531 - y2_output_root_mean_squared_error: 0.5278 - val_loss: 1.7210 - val_y1_output_loss: 0.2483 - val_y2_output_loss: 1.4147 - val_y1_output_root_mean_squared_error: 0.5041 - val_y2_output_root_mean_squared_error: 1.2112
# Epoch 476/500
# 614/614 [==============================] - 0s 148us/sample - loss: 0.5701 - y1_output_loss: 0.1747 - y2_output_loss: 0.3924 - y1_output_root_mean_squared_error: 0.4195 - y2_output_root_mean_squared_error: 0.6278 - val_loss: 0.7968 - val_y1_output_loss: 0.1342 - val_y2_output_loss: 0.6378 - val_y1_output_root_mean_squared_error: 0.3709 - val_y2_output_root_mean_squared_error: 0.8119
# Epoch 477/500
# 614/614 [==============================] - 0s 142us/sample - loss: 0.3638 - y1_output_loss: 0.1118 - y2_output_loss: 0.2490 - y1_output_root_mean_squared_error: 0.3359 - y2_output_root_mean_squared_error: 0.5010 - val_loss: 0.9005 - val_y1_output_loss: 0.1833 - val_y2_output_loss: 0.6921 - val_y1_output_root_mean_squared_error: 0.4339 - val_y2_output_root_mean_squared_error: 0.8439
# Epoch 478/500
# 614/614 [==============================] - 0s 143us/sample - loss: 0.3645 - y1_output_loss: 0.1114 - y2_output_loss: 0.2626 - y1_output_root_mean_squared_error: 0.3251 - y2_output_root_mean_squared_error: 0.5087 - val_loss: 4.0649 - val_y1_output_loss: 0.8458 - val_y2_output_loss: 3.1059 - val_y1_output_root_mean_squared_error: 0.9299 - val_y2_output_root_mean_squared_error: 1.7889
# Epoch 479/500
# 614/614 [==============================] - 0s 152us/sample - loss: 0.3709 - y1_output_loss: 0.1157 - y2_output_loss: 0.2557 - y1_output_root_mean_squared_error: 0.3399 - y2_output_root_mean_squared_error: 0.5053 - val_loss: 1.1607 - val_y1_output_loss: 0.1591 - val_y2_output_loss: 0.9629 - val_y1_output_root_mean_squared_error: 0.4042 - val_y2_output_root_mean_squared_error: 0.9986
# Epoch 480/500
# 614/614 [==============================] - 0s 149us/sample - loss: 0.4430 - y1_output_loss: 0.1319 - y2_output_loss: 0.3082 - y1_output_root_mean_squared_error: 0.3642 - y2_output_root_mean_squared_error: 0.5571 - val_loss: 0.9169 - val_y1_output_loss: 0.1485 - val_y2_output_loss: 0.7421 - val_y1_output_root_mean_squared_error: 0.3896 - val_y2_output_root_mean_squared_error: 0.8747
# Epoch 481/500
# 614/614 [==============================] - 0s 148us/sample - loss: 0.5125 - y1_output_loss: 0.1487 - y2_output_loss: 0.3636 - y1_output_root_mean_squared_error: 0.3863 - y2_output_root_mean_squared_error: 0.6027 - val_loss: 1.1234 - val_y1_output_loss: 0.2152 - val_y2_output_loss: 0.8782 - val_y1_output_root_mean_squared_error: 0.4652 - val_y2_output_root_mean_squared_error: 0.9524
# Epoch 482/500
# 614/614 [==============================] - 0s 151us/sample - loss: 0.3664 - y1_output_loss: 0.1115 - y2_output_loss: 0.2562 - y1_output_root_mean_squared_error: 0.3339 - y2_output_root_mean_squared_error: 0.5048 - val_loss: 1.3296 - val_y1_output_loss: 0.1464 - val_y2_output_loss: 1.1362 - val_y1_output_root_mean_squared_error: 0.3887 - val_y2_output_root_mean_squared_error: 1.0856
# Epoch 483/500
# 614/614 [==============================] - 0s 149us/sample - loss: 0.3677 - y1_output_loss: 0.1144 - y2_output_loss: 0.2547 - y1_output_root_mean_squared_error: 0.3388 - y2_output_root_mean_squared_error: 0.5029 - val_loss: 0.9065 - val_y1_output_loss: 0.1334 - val_y2_output_loss: 0.7532 - val_y1_output_root_mean_squared_error: 0.3710 - val_y2_output_root_mean_squared_error: 0.8768
# Epoch 484/500
# 614/614 [==============================] - 0s 150us/sample - loss: 0.3104 - y1_output_loss: 0.1114 - y2_output_loss: 0.2033 - y1_output_root_mean_squared_error: 0.3287 - y2_output_root_mean_squared_error: 0.4499 - val_loss: 1.7135 - val_y1_output_loss: 0.4237 - val_y2_output_loss: 1.2480 - val_y1_output_root_mean_squared_error: 0.6615 - val_y2_output_root_mean_squared_error: 1.1296
# Epoch 485/500
# 614/614 [==============================] - 0s 146us/sample - loss: 0.4285 - y1_output_loss: 0.1324 - y2_output_loss: 0.2935 - y1_output_root_mean_squared_error: 0.3651 - y2_output_root_mean_squared_error: 0.5433 - val_loss: 0.8808 - val_y1_output_loss: 0.1676 - val_y2_output_loss: 0.6864 - val_y1_output_root_mean_squared_error: 0.4131 - val_y2_output_root_mean_squared_error: 0.8427
# Epoch 486/500
# 614/614 [==============================] - 0s 152us/sample - loss: 0.4820 - y1_output_loss: 0.1554 - y2_output_loss: 0.3232 - y1_output_root_mean_squared_error: 0.3956 - y2_output_root_mean_squared_error: 0.5706 - val_loss: 0.9205 - val_y1_output_loss: 0.1790 - val_y2_output_loss: 0.7191 - val_y1_output_root_mean_squared_error: 0.4304 - val_y2_output_root_mean_squared_error: 0.8575
# Epoch 487/500
# 614/614 [==============================] - 0s 156us/sample - loss: 0.3501 - y1_output_loss: 0.1158 - y2_output_loss: 0.2320 - y1_output_root_mean_squared_error: 0.3410 - y2_output_root_mean_squared_error: 0.4836 - val_loss: 0.8732 - val_y1_output_loss: 0.1786 - val_y2_output_loss: 0.6686 - val_y1_output_root_mean_squared_error: 0.4288 - val_y2_output_root_mean_squared_error: 0.8303
# Epoch 488/500
# 614/614 [==============================] - 0s 179us/sample - loss: 0.3465 - y1_output_loss: 0.1124 - y2_output_loss: 0.2397 - y1_output_root_mean_squared_error: 0.3291 - y2_output_root_mean_squared_error: 0.4881 - val_loss: 1.2483 - val_y1_output_loss: 0.3245 - val_y2_output_loss: 0.9110 - val_y1_output_root_mean_squared_error: 0.5691 - val_y2_output_root_mean_squared_error: 0.9615
# Epoch 489/500
# 614/614 [==============================] - 0s 152us/sample - loss: 0.3972 - y1_output_loss: 0.1225 - y2_output_loss: 0.2745 - y1_output_root_mean_squared_error: 0.3503 - y2_output_root_mean_squared_error: 0.5239 - val_loss: 0.9405 - val_y1_output_loss: 0.1451 - val_y2_output_loss: 0.7694 - val_y1_output_root_mean_squared_error: 0.3843 - val_y2_output_root_mean_squared_error: 0.8904
# Epoch 490/500
# 614/614 [==============================] - 0s 153us/sample - loss: 0.3436 - y1_output_loss: 0.1109 - y2_output_loss: 0.2316 - y1_output_root_mean_squared_error: 0.3334 - y2_output_root_mean_squared_error: 0.4821 - val_loss: 1.1038 - val_y1_output_loss: 0.1874 - val_y2_output_loss: 0.8848 - val_y1_output_root_mean_squared_error: 0.4341 - val_y2_output_root_mean_squared_error: 0.9568
# Epoch 491/500
# 614/614 [==============================] - 0s 156us/sample - loss: 0.3935 - y1_output_loss: 0.1442 - y2_output_loss: 0.2484 - y1_output_root_mean_squared_error: 0.3814 - y2_output_root_mean_squared_error: 0.4981 - val_loss: 1.5472 - val_y1_output_loss: 0.1730 - val_y2_output_loss: 1.3210 - val_y1_output_root_mean_squared_error: 0.4224 - val_y2_output_root_mean_squared_error: 1.1699
# Epoch 492/500
# 614/614 [==============================] - 0s 148us/sample - loss: 0.4761 - y1_output_loss: 0.1307 - y2_output_loss: 0.3581 - y1_output_root_mean_squared_error: 0.3599 - y2_output_root_mean_squared_error: 0.5887 - val_loss: 1.8284 - val_y1_output_loss: 0.3530 - val_y2_output_loss: 1.4326 - val_y1_output_root_mean_squared_error: 0.6001 - val_y2_output_root_mean_squared_error: 1.2117
# Epoch 493/500
# 614/614 [==============================] - 0s 150us/sample - loss: 0.4638 - y1_output_loss: 0.1380 - y2_output_loss: 0.3237 - y1_output_root_mean_squared_error: 0.3720 - y2_output_root_mean_squared_error: 0.5704 - val_loss: 1.0525 - val_y1_output_loss: 0.2152 - val_y2_output_loss: 0.8185 - val_y1_output_root_mean_squared_error: 0.4642 - val_y2_output_root_mean_squared_error: 0.9149
# Epoch 494/500
# 614/614 [==============================] - 0s 155us/sample - loss: 0.3799 - y1_output_loss: 0.1191 - y2_output_loss: 0.2590 - y1_output_root_mean_squared_error: 0.3463 - y2_output_root_mean_squared_error: 0.5099 - val_loss: 0.9061 - val_y1_output_loss: 0.1746 - val_y2_output_loss: 0.7123 - val_y1_output_root_mean_squared_error: 0.4232 - val_y2_output_root_mean_squared_error: 0.8527
# Epoch 495/500
# 614/614 [==============================] - 0s 159us/sample - loss: 0.4679 - y1_output_loss: 0.1521 - y2_output_loss: 0.3150 - y1_output_root_mean_squared_error: 0.3917 - y2_output_root_mean_squared_error: 0.5607 - val_loss: 0.8295 - val_y1_output_loss: 0.1635 - val_y2_output_loss: 0.6398 - val_y1_output_root_mean_squared_error: 0.4108 - val_y2_output_root_mean_squared_error: 0.8128
# Epoch 496/500
# 614/614 [==============================] - 0s 156us/sample - loss: 0.3541 - y1_output_loss: 0.1271 - y2_output_loss: 0.2308 - y1_output_root_mean_squared_error: 0.3514 - y2_output_root_mean_squared_error: 0.4802 - val_loss: 0.9717 - val_y1_output_loss: 0.2809 - val_y2_output_loss: 0.6652 - val_y1_output_root_mean_squared_error: 0.5368 - val_y2_output_root_mean_squared_error: 0.8268
# Epoch 497/500
# 614/614 [==============================] - 0s 156us/sample - loss: 0.4329 - y1_output_loss: 0.1499 - y2_output_loss: 0.3161 - y1_output_root_mean_squared_error: 0.3812 - y2_output_root_mean_squared_error: 0.5363 - val_loss: 3.9985 - val_y1_output_loss: 0.6963 - val_y2_output_loss: 3.2810 - val_y1_output_root_mean_squared_error: 0.8433 - val_y2_output_root_mean_squared_error: 1.8131
# Epoch 498/500
# 614/614 [==============================] - 0s 153us/sample - loss: 0.7012 - y1_output_loss: 0.1799 - y2_output_loss: 0.5193 - y1_output_root_mean_squared_error: 0.4258 - y2_output_root_mean_squared_error: 0.7210 - val_loss: 0.7805 - val_y1_output_loss: 0.1457 - val_y2_output_loss: 0.6135 - val_y1_output_root_mean_squared_error: 0.3849 - val_y2_output_root_mean_squared_error: 0.7952
# Epoch 499/500
# 614/614 [==============================] - 0s 153us/sample - loss: 0.4598 - y1_output_loss: 0.1381 - y2_output_loss: 0.3202 - y1_output_root_mean_squared_error: 0.3728 - y2_output_root_mean_squared_error: 0.5664 - val_loss: 1.0368 - val_y1_output_loss: 0.1299 - val_y2_output_loss: 0.8721 - val_y1_output_root_mean_squared_error: 0.3656 - val_y2_output_root_mean_squared_error: 0.9503
# Epoch 500/500
# 614/614 [==============================] - 0s 158us/sample - loss: 0.6866 - y1_output_loss: 0.1587 - y2_output_loss: 0.5237 - y1_output_root_mean_squared_error: 0.3995 - y2_output_root_mean_squared_error: 0.7259 - val_loss: 0.9407 - val_y1_output_loss: 0.1541 - val_y2_output_loss: 0.7566 - val_y1_output_root_mean_squared_error: 0.3983 - val_y2_output_root_mean_squared_error: 0.8843

# %% [markdown]
# ## Evaluate the Model and Plot Metrics

# %%
# Test the model and print loss and mse for both outputs
loss, Y1_loss, Y2_loss, Y1_rmse, Y2_rmse = model.evaluate(x=norm_test_X, y=test_Y)
print("Loss = {}, Y1_loss = {}, Y1_mse = {}, Y2_loss = {}, Y2_mse = {}".format(loss, Y1_loss, Y1_rmse, Y2_loss, Y2_rmse))
# Out:
# 154/154 [==============================] - 0s 44us/sample - loss: 0.9407 - y1_output_loss: 0.1595 - y2_output_loss: 0.7943 - y1_output_root_mean_squared_error: 0.3983 - y2_output_root_mean_squared_error: 0.8843
# Loss = 0.9406837457186216, Y1_loss = 0.15947893261909485, Y1_mse = 0.3983202278614044, Y2_loss = 0.7943457961082458, Y2_mse = 0.8843216300010681

# %%
# Plot the loss and mse
Y_pred = model.predict(norm_test_X)
plot_diff(test_Y[0], Y_pred[0], title='Y1')
plot_diff(test_Y[1], Y_pred[1], title='Y2')
plot_metrics(metric_name='y1_output_root_mean_squared_error', title='Y1 RMSE', ylim=6)
plot_metrics(metric_name='y2_output_root_mean_squared_error', title='Y2 RMSE', ylim=7)
